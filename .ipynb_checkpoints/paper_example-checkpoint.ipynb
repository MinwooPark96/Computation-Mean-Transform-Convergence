# %%
from Computation_Matrix.meantransform import MeanTrans

import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# ## Convergence of the iterated mean transforms of a 2 × 2 matrix; its Algorithm
#
# #### Ji Eun Lee and Min Woo Park
#
# #### Abstract
#
# For the polar decomposition $T = U |T | ∈ L(H)$ (defined below), the mean
# transform ̂ T of T is defined by
#
#
# $T = \frac{1}{2} (T + |T |U ).$
#
#
# We prove that the iterated mean transform of a 2 × 2 matrix converges
# a normal matrix. Moreover, we provide the computation method of the
# iterated mean transforms with an Algorithm in Python.

# %% [markdown]
# #### Example 2.4.
#  If
# $T=
# \begin{pmatrix}
# 0&1\\
# 0&0
# \end{pmatrix}$ on ${\mathbb C}^2$, then $T:=U|T|=\begin{pmatrix}
#     0 & 1 \\
#    0 & 0
#     \end{pmatrix}\begin{pmatrix}
#     0&0\\
#     0& 1
#     \end{pmatrix}$ is the polar decomposition of $T$.
# Thus
# $
#     \widehat{T}=\frac{1}{2}(T+\widetilde{T}^{(D)})=\frac{1}{2}
#     \begin{pmatrix}
#     0&1\\
#     0&0
#     \end{pmatrix}
# $
# and so $\widehat{T}$ is normal.
# Hence $\widehat{T}^{(n)}$ converges to normal as $n\rightarrow \infty$.

# %%
T=np.matrix([0,1,0,0]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,10)

print(Transformer[1])
Transformer.process(1)
Transformer.normal_calculator()
Transformer.normal_plot()
# Out:
# [[0.  0.5]
#  [0.  0. ]]
# ===============<START>===============
#
# T_hat(0)
#  [[0 1]
#  [0 0]]
#
# W
#  [[1. 0.]
#  [0. 1.]]
#
# Sigma
#  [[1. 0.]
#  [0. 0.]]
#
# V_h
#  [[ 0.  1.]
#  [-1.  0.]]
#
# W\Sigma V^*
#  [[0. 1.]
#  [0. 0.]]
#
# WV^*
#  [[ 0.  1.]
#  [-1.  0.]]
#
# V
#  [[ 0. -1.]
#  [ 1.  0.]]
#
# Sigma_pinv
#  [[1. 0.]
#  [0. 0.]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[0. 1.]
#  [0. 0.]]
#
# |T|
#  [[0. 0.]
#  [0. 1.]]
#
# U|T|
#  [[0. 1.]
#  [0. 0.]]
#
# T_duggal
#  [[0. 0.]
#  [0. 0.]]
#
# |T|U [[0. 0.]
#  [0. 0.]]
#
# T_hat(1)
#  [[0.  0.5]
#  [0.  0. ]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[0.  0.5]
#  [0.  0. ]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %%
T=np.matrix([0,27890,0,0]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,10)

print(Transformer[1])
Transformer.process(1)
Transformer.normal_calculator()
Transformer.normal_plot()
# Out:
# [[    0. 13945.]
#  [    0.     0.]]
# ===============<START>===============
#
# T_hat(0)
#  [[    0 27890]
#  [    0     0]]
#
# W
#  [[1. 0.]
#  [0. 1.]]
#
# Sigma
#  [[27890.     0.]
#  [    0.     0.]]
#
# V_h
#  [[ 0.  1.]
#  [-1.  0.]]
#
# W\Sigma V^*
#  [[    0. 27890.]
#  [    0.     0.]]
#
# WV^*
#  [[ 0.  1.]
#  [-1.  0.]]
#
# V
#  [[ 0. -1.]
#  [ 1.  0.]]
#
# Sigma_pinv
#  [[0. 0.]
#  [0. 0.]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[0. 1.]
#  [0. 0.]]
#
# |T|
#  [[    0.     0.]
#  [    0. 27890.]]
#
# U|T|
#  [[    0. 27890.]
#  [    0.     0.]]
#
# T_duggal
#  [[0. 0.]
#  [0. 0.]]
#
# |T|U [[0. 0.]
#  [0. 0.]]
#
# T_hat(1)
#  [[    0. 13945.]
#  [    0.     0.]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[    0. 13945.]
#  [    0.     0.]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %% [markdown]
# #### Example 2.5.
#
# Let $T=
# \begin{pmatrix}
# 0 & 1 \\
# 0 & 1
# \end{pmatrix}$.
# Then $T=U|T|=
# \begin{pmatrix}
#     0 & \frac{\sqrt{2}}{2} \\
#    0 & \frac{\sqrt{2}}{2}
#     \end{pmatrix}\begin{pmatrix}
#     0&0\\
#    0& \sqrt{2}
#     \end{pmatrix}$ is the polar decomposition of $T$ and $\widetilde{T}^D=
# \begin{pmatrix}
#     0&0\\
#    0& \sqrt{2}
#     \end{pmatrix}
# \begin{pmatrix}
#     0 & \frac{\sqrt{2}}{2} \\
#    0 & \frac{\sqrt{2}}{2}
#     \end{pmatrix}=
# \begin{pmatrix}
# 0 & 0\\
# 0 & 1\\
# \end{pmatrix}$. Thus
# \begin{align*}
#     T_1=\widehat{T}=\frac{1}{2}\left[
#     \begin{pmatrix}
# 0 & 1\\
# 0 & 1\\
# \end{pmatrix}+
# \begin{pmatrix}
# 0 & 0\\
# 0 & 1\\
# \end{pmatrix}\right]=\frac{1}{2}\begin{pmatrix}
# 0 & 1\\
# 0 & 2\\
# \end{pmatrix}=
# \begin{pmatrix}
# 0 & \frac{1}{2}\\
# 0 & 1\\
# \end{pmatrix}.
# \end{align*}
# And so
# \begin{align*}
# &|T_1|=(\widehat{T}^*\widehat{T})^\frac{1}{2}
#     =\left[
#     \begin{pmatrix}
# 0 & 0\\
# \frac{1}{2} & 1\\
# \end{pmatrix}
# \begin{pmatrix}
# 0 & \frac{1}{2}\\
# 0 & 1\\
# \end{pmatrix}\right]^\frac{1}{2}
# =
# \begin{pmatrix}
# 0 & 0\\
# 0 & \frac{\sqrt{5}}{2}\\
# \end{pmatrix} and
# &U_1=\frac{1}{\sqrt{5}}
# \begin{pmatrix}
# 0 & 1\\
# 0 & 2
# \end{pmatrix}.
# \end{align*}
# Therefore
# \begin{align*}
#     T_2=\widehat{T_1}&=
#     \frac{1}{2}\left[
#     \begin{pmatrix}
# 0 & \frac{1}{2}\\
# 0 & 1\\
# \end{pmatrix}+
# \begin{pmatrix}
# 0 & 0\\
# 0 & \frac{\sqrt{5}}{2}\\
# \end{pmatrix}
# \frac{1}{\sqrt{5}}
# \begin{pmatrix}
# 0 & 1\\
# 0 & 2\\
# \end{pmatrix}
# \right]\\
# &=\frac{1}{2}
# \begin{pmatrix}
# 0 & \frac{1}{2}\\
# 0 & 2\\
# \end{pmatrix}=
# \begin{pmatrix}
# 0 & \left(\frac{1}{2}\right)^2\\
# 0 & 1\\
# \end{pmatrix}.
# \end{align*}

# %%
T=np.matrix([0,1,0,1]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,10)

print(Transformer[1]) 
Transformer.process(1)
Transformer.normal_calculator()
Transformer.normal_plot()
# Out:
# [[0.  0.5]
#  [0.  1. ]]
# ===============<START>===============
#
# T_hat(0)
#  [[0 1]
#  [0 1]]
#
# W
#  [[ 0.7071 -0.7071]
#  [ 0.7071  0.7071]]
#
# Sigma
#  [[1.4142 0.    ]
#  [0.     0.    ]]
#
# V_h
#  [[ 0.  1.]
#  [-1.  0.]]
#
# W\Sigma V^*
#  [[0. 1.]
#  [0. 1.]]
#
# WV^*
#  [[ 0.7071  0.7071]
#  [-0.7071  0.7071]]
#
# V
#  [[ 0. -1.]
#  [ 1.  0.]]
#
# Sigma_pinv
#  [[0.7071 0.    ]
#  [0.     0.    ]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[0.     0.7071]
#  [0.     0.7071]]
#
# |T|
#  [[0.     0.    ]
#  [0.     1.4142]]
#
# U|T|
#  [[0. 1.]
#  [0. 1.]]
#
# T_duggal
#  [[0. 0.]
#  [0. 1.]]
#
# |T|U [[0. 0.]
#  [0. 1.]]
#
# T_hat(1)
#  [[0.  0.5]
#  [0.  1. ]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[0.  0.5]
#  [0.  1. ]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %%
# where R = 2.789
# R^2 + 1 ~= 8.7785
# 1/sqrt(R^2 + 1) ~= 0.33751
# R/sqrt(R^2 + 1) ~= 0.94132

T=np.matrix([0,2.789,0,1]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,10)

print(Transformer[1])
Transformer.process(1,dicimals=10)

# sqrt(R^2/4+1) ~= 1.71599
# 1/sqrt(R*R/4+1) ~= 0.58275
# (R/2)/sqrt(R*R/4+1) ~= 0.81264

print(Transformer[2])
Transformer.process(2,dicimals=10)
T_5 = Transformer[5]
print(np.linalg.eig(T)[0])
print(np.linalg.eig(T_5)[0])
# Out:
# [[0.     1.3945]
#  [0.     1.    ]]
# ===============<START>===============
#
# T_hat(0)
#  [[0.    2.789]
#  [0.    1.   ]]
#
# W
#  [[ 0.9413212  -0.33751208]
#  [ 0.33751208  0.9413212 ]]
#
# Sigma
#  [[2.9628569 0.       ]
#  [0.        0.       ]]
#
# V_h
#  [[ 0.  1.]
#  [-1.  0.]]
#
# W\Sigma V^*
#  [[0.    2.789]
#  [0.    1.   ]]
#
# WV^*
#  [[ 0.33751208  0.9413212 ]
#  [-0.9413212   0.33751208]]
#
# V
#  [[ 0. -1.]
#  [ 1.  0.]]
#
# Sigma_pinv
#  [[0.33751208 0.        ]
#  [0.         0.        ]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[0.         0.9413212 ]
#  [0.         0.33751208]]
#
# |T|
#  [[0.        0.       ]
#  [0.        2.9628569]]
#
# U|T|
#  [[0.    2.789]
#  [0.    1.   ]]
#
# T_duggal
#  [[0. 0.]
#  [0. 1.]]
#
# |T|U [[0. 0.]
#  [0. 1.]]
#
# T_hat(1)
#  [[0.     1.3945]
#  [0.     1.    ]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[0.     1.3945]
#  [0.     1.    ]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# [[0.      0.69725]
#  [0.      1.     ]]
# ===============<START>===============
#
# T_hat(1)
#  [[0.     1.3945]
#  [0.     1.    ]]
#
# W
#  [[ 0.81264924 -0.58275313]
#  [ 0.58275313  0.81264924]]
#
# Sigma
#  [[1.7159925 0.       ]
#  [0.        0.       ]]
#
# V_h
#  [[ 0.  1.]
#  [-1.  0.]]
#
# W\Sigma V^*
#  [[0.     1.3945]
#  [0.     1.    ]]
#
# WV^*
#  [[ 0.58275313  0.81264924]
#  [-0.81264924  0.58275313]]
#
# V
#  [[ 0. -1.]
#  [ 1.  0.]]
#
# Sigma_pinv
#  [[0.58275313 0.        ]
#  [0.         0.        ]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[0.         0.81264924]
#  [0.         0.58275313]]
#
# |T|
#  [[0.        0.       ]
#  [0.        1.7159925]]
#
# U|T|
#  [[0.     1.3945]
#  [0.     1.    ]]
#
# T_duggal
#  [[0. 0.]
#  [0. 1.]]
#
# |T|U [[0. 0.]
#  [0. 1.]]
#
# T_hat(2)
#  [[0.      0.69725]
#  [0.      1.     ]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[0.      0.69725]
#  [0.      1.     ]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# [0. 1.]
# [0. 1.]

# %% [markdown]
# #### Example 2.9.
#
# Let $T=
# \begin{pmatrix}
# i & 2 \\
# 0 & -i
# \end{pmatrix}$.
# Then
# \begin{equation*}
#     |T|^2=T^*T =
#     \begin{pmatrix}
#         -i & 0 \\
#         2 & i
#     \end{pmatrix}
#     \begin{pmatrix}
#         i & 2 \\
#         0 & -i
#     \end{pmatrix}
#     =
#     \begin{pmatrix}
#         1 & -2i \\
#         2i & 5
#     \end{pmatrix}.
# \end{equation*}
# By Lemma 2.7, we have
# \begin{equation*}
#     |T|=\frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         1 & -i \\
#         i & 3
#     \end{pmatrix}~\text{and}~
#     |T|^{-1}=\frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         3 & i \\
#         -i & 1
#     \end{pmatrix}.
# \end{equation*}
# Thus
# \begin{align*}
#     &U=T|T|^{-1}=
#     \begin{pmatrix}
#         i & 2 \\
#         0 & -i
#     \end{pmatrix}
#     \frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         3 & i \\
#         -i & 1
#     \end{pmatrix}=
#     \frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         i & 1 \\
#         -1 & -i
#     \end{pmatrix}\quad \text{and}\\
#     &\widetilde{T}^D = |T|U =
#     \frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         1 & -i \\
#         i & 3
#     \end{pmatrix}
#     \frac{1}{\sqrt{2}}
#     \begin{pmatrix}
#         i & 1 \\
#         -1 & -i
#     \end{pmatrix}=
#     \frac{1}{2}
#     \begin{pmatrix}
#         2i & 0 \\
#         -4 & -2i
#     \end{pmatrix}=
#     \begin{pmatrix}
#         i & 0 \\
#         -2 & i
#     \end{pmatrix}.
# \end{align*}
# Hence we get
# \begin{equation*}
#     \widehat{T}=\frac{1}{2}(T+\widetilde{T}^D)=\frac{1}{2}\left(
#     \begin{pmatrix}
#         i & 2 \\
#         0 & -i
#     \end{pmatrix}+
#     \begin{pmatrix}
#         i & 0 \\
#         -2 & i
#     \end{pmatrix}
#     \right)
#     =
#     \begin{pmatrix}
#         i & 1 \\
#         -1 & -i
#     \end{pmatrix}.
# \end{equation*}
# Since
# \begin{align*}
#     det(\widehat{T}-\lambda I_2 ) =
#     \begin{vmatrix}
#     i-\lambda & 1\\
#     -1 & -1-\lambda
#     \end{vmatrix}
#     =(i-\lambda)(-i-\lambda)+1
#     =\lambda^2+2
#     =0,
# \end{align*}
# it follows that the eigenvalues of $\widehat{T}$ are $\pm \sqrt{2}i$.

# %%
T=np.matrix([complex(0,1),2,0,complex(0,-1)]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,10)

Transformer.process(1,dicimals=10)
Transformer.normal_calculator()
Transformer.normal_plot()
# Out:
# ===============<START>===============
#
# T_hat(0)
#  [[0.+1.j 2.+0.j]
#  [0.+0.j 0.-1.j]]
#
# W
#  [[ 0.        -0.92387953j  0.        -0.38268343j]
#  [-0.38268343+0.j          0.92387953+0.j        ]]
#
# Sigma
#  [[2.41421356 0.        ]
#  [0.         0.41421356]]
#
# V_h
#  [[-0.38268343+0.j          0.        +0.92387953j]
#  [-0.92387953+0.j          0.        -0.38268343j]]
#
# W\Sigma V^*
#  [[0.+1.j 2.+0.j]
#  [0.+0.j 0.-1.j]]
#
# WV^*
#  [[ 0.        +0.70710678j  0.70710678+0.j        ]
#  [-0.70710678+0.j          0.        -0.70710678j]]
#
# V
#  [[-0.38268343-0.j         -0.92387953-0.j        ]
#  [ 0.        -0.92387953j  0.        +0.38268343j]]
#
# Sigma_pinv
#  [[0.41421356 0.        ]
#  [0.         2.41421356]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.        +0.70710678j  0.70710678+0.j        ]
#  [-0.70710678+0.j          0.        -0.70710678j]]
#
# |T|
#  [[0.70710678+0.j         0.        -0.70710678j]
#  [0.        +0.70710678j 2.12132034+0.j        ]]
#
# U|T|
#  [[ 0.+1.j  2.+0.j]
#  [-0.+0.j  0.-1.j]]
#
# T_duggal
#  [[ 0.+1.j  0.+0.j]
#  [-2.+0.j  0.-1.j]]
#
# |T|U [[ 0.+1.j  0.+0.j]
#  [-2.+0.j  0.-1.j]]
#
# T_hat(1)
#  [[ 0.+1.j  1.+0.j]
#  [-1.+0.j  0.-1.j]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 0.+1.j  1.+0.j]
#  [-1.+0.j  0.-1.j]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %% [markdown]
# #### Example 3.1
# Let $T=\begin{pmatrix} 2 & -1 \\ 3 & 4\end{pmatrix}$ in $M_2(\cal{C})$. Then, by using Python

# %%
T=np.matrix([2,-1,3,4]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,50)

Transformer.normal_calculator()
Transformer.normal_plot()
for i in range(1,11):
    Transformer.process(i)
# Out:
# ===============<START>===============
#
# T_hat(0)
#  [[ 2 -1]
#  [ 3  4]]
#
# W
#  [[-0.0985 -0.9951]
#  [-0.9951  0.0985]]
#
# Sigma
#  [[5.0198 0.    ]
#  [0.     2.1913]]
#
# V_h
#  [[-0.634  -0.7733]
#  [-0.7733  0.634 ]]
#
# W\Sigma V^*
#  [[ 2. -1.]
#  [ 3.  4.]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.63398891 -0.77334214]
#  [-0.77334214  0.63398891]]
#
# Sigma_pinv
#  [[0.1992 0.    ]
#  [0.     0.4563]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[3.3282 1.3868]
#  [1.3868 3.8829]]
#
# U|T|
#  [[ 2. -1.]
#  [ 3.  4.]]
#
# T_duggal
#  [[ 3.5385 -0.6923]
#  [ 3.3077  2.4615]]
#
# |T|U [[ 3.5385 -0.6923]
#  [ 3.3077  2.4615]]
#
# T_hat(1)
#  [[ 2.7692 -0.8462]
#  [ 3.1538  3.2308]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 2.7692 -0.8462]
#  [ 3.1538  3.2308]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(1)
#  [[ 2.7692 -0.8462]
#  [ 3.1538  3.2308]]
#
# W
#  [[-0.3827 -0.9239]
#  [-0.9239  0.3827]]
#
# Sigma
#  [[4.7822 0.    ]
#  [0.     2.4289]]
#
# V_h
#  [[-0.8309 -0.5564]
#  [-0.5564  0.8309]]
#
# W\Sigma V^*
#  [[ 2.7692 -0.8462]
#  [ 3.1538  3.2308]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.83088802 -0.55643966]
#  [-0.55643966  0.83088802]]
#
# Sigma_pinv
#  [[0.2091 0.    ]
#  [0.     0.4117]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[4.0536 1.0881]
#  [1.0881 3.1575]]
#
# U|T|
#  [[ 2.7692 -0.8462]
#  [ 3.1538  3.2308]]
#
# T_duggal
#  [[ 3.9763 -1.3432]
#  [ 2.6568  2.0237]]
#
# |T|U [[ 3.9763 -1.3432]
#  [ 2.6568  2.0237]]
#
# T_hat(2)
#  [[ 3.3728 -1.0947]
#  [ 2.9053  2.6272]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 3.3728 -1.0947]
#  [ 2.9053  2.6272]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(2)
#  [[ 3.3728 -1.0947]
#  [ 2.9053  2.6272]]
#
# W
#  [[-0.634  -0.7733]
#  [-0.7733  0.634 ]]
#
# Sigma
#  [[4.5846 0.    ]
#  [0.     2.6265]]
#
# V_h
#  [[-0.9565 -0.2918]
#  [-0.2918  0.9565]]
#
# W\Sigma V^*
#  [[ 3.3728 -1.0947]
#  [ 2.9053  2.6272]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.95648369 -0.29178579]
#  [-0.29178579  0.95648369]]
#
# Sigma_pinv
#  [[0.2181 0.    ]
#  [0.     0.3807]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[4.4179 0.5465]
#  [0.5465 2.7932]]
#
# U|T|
#  [[ 3.3728 -1.0947]
#  [ 2.9053  2.6272]]
#
# T_duggal
#  [[ 3.9791 -1.9959]
#  [ 2.0041  2.0209]]
#
# |T|U [[ 3.9791 -1.9959]
#  [ 2.0041  2.0209]]
#
# T_hat(3)
#  [[ 3.6759 -1.5453]
#  [ 2.4547  2.3241]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 3.6759 -1.5453]
#  [ 2.4547  2.3241]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(3)
#  [[ 3.6759 -1.5453]
#  [ 2.4547  2.3241]]
#
# W
#  [[-0.8309 -0.5564]
#  [-0.5564  0.8309]]
#
# Sigma
#  [[4.4202 0.    ]
#  [0.     2.7909]]
#
# V_h
#  [[-1.     -0.0021]
#  [-0.0021  1.    ]]
#
# W\Sigma V^*
#  [[ 3.6759 -1.5453]
#  [ 2.4547  2.3241]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.99999781 -0.00209204]
#  [-0.00209204  0.99999781]]
#
# Sigma_pinv
#  [[0.2262 0.    ]
#  [0.     0.3583]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[4.4202e+00 3.4000e-03]
#  [3.4000e-03 2.7909e+00]]
#
# U|T|
#  [[ 3.6759 -1.5453]
#  [ 2.4547  2.3241]]
#
# T_duggal
#  [[ 3.6797 -2.449 ]
#  [ 1.551   2.3203]]
#
# |T|U [[ 3.6797 -2.449 ]
#  [ 1.551   2.3203]]
#
# T_hat(4)
#  [[ 3.6778 -1.9972]
#  [ 2.0028  2.3222]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 3.6778 -1.9972]
#  [ 2.0028  2.3222]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(4)
#  [[ 3.6778 -1.9972]
#  [ 2.0028  2.3222]]
#
# W
#  [[-0.9565 -0.2918]
#  [-0.2918  0.9565]]
#
# Sigma
#  [[4.2834 0.    ]
#  [0.     2.9277]]
#
# V_h
#  [[-0.9577  0.2878]
#  [ 0.2878  0.9577]]
#
# W\Sigma V^*
#  [[ 3.6778 -1.9972]
#  [ 2.0028  2.3222]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.95769617  0.28778124]
#  [ 0.28778124  0.95769617]]
#
# Sigma_pinv
#  [[0.2335 0.    ]
#  [0.     0.3416]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[ 4.1711 -0.3736]
#  [-0.3736  3.04  ]]
#
# U|T|
#  [[ 3.6778 -1.9972]
#  [ 2.0028  2.3222]]
#
# T_duggal
#  [[ 3.2633 -2.6246]
#  [ 1.3754  2.7367]]
#
# |T|U [[ 3.2633 -2.6246]
#  [ 1.3754  2.7367]]
#
# T_hat(5)
#  [[ 3.4706 -2.3109]
#  [ 1.6891  2.5294]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 3.4706 -2.3109]
#  [ 1.6891  2.5294]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(5)
#  [[ 3.4706 -2.3109]
#  [ 1.6891  2.5294]]
#
# W
#  [[-1.     -0.0021]
#  [-0.0021  1.    ]]
#
# Sigma
#  [[4.1695 0.    ]
#  [0.     3.0416]]
#
# V_h
#  [[-0.8332  0.553 ]
#  [ 0.553   0.8332]]
#
# W\Sigma V^*
#  [[ 3.4706 -2.3109]
#  [ 1.6891  2.5294]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.83320893  0.5529583 ]
#  [ 0.5529583   0.83320893]]
#
# Sigma_pinv
#  [[0.2398 0.    ]
#  [0.     0.3288]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[ 3.8246 -0.5197]
#  [-0.5197  3.3865]]
#
# U|T|
#  [[ 3.4706 -2.3109]
#  [ 1.6891  2.5294]]
#
# T_duggal
#  [[ 2.894  -2.5539]
#  [ 1.4461  3.106 ]]
#
# |T|U [[ 2.894  -2.5539]
#  [ 1.4461  3.106 ]]
#
# T_hat(6)
#  [[ 3.1823 -2.4324]
#  [ 1.5676  2.8177]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 3.1823 -2.4324]
#  [ 1.5676  2.8177]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(6)
#  [[ 3.1823 -2.4324]
#  [ 1.5676  2.8177]]
#
# W
#  [[-0.9577  0.2878]
#  [ 0.2878  0.9577]]
#
# Sigma
#  [[4.0748 0.    ]
#  [0.     3.1363]]
#
# V_h
#  [[-0.6372  0.7707]
#  [ 0.7707  0.6372]]
#
# W\Sigma V^*
#  [[ 3.1823 -2.4324]
#  [ 1.5676  2.8177]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.63721907  0.77068272]
#  [ 0.77068272  0.63721907]]
#
# Sigma_pinv
#  [[0.2454 0.    ]
#  [0.     0.3188]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[ 3.5174 -0.4609]
#  [-0.4609  3.6937]]
#
# U|T|
#  [[ 3.1823 -2.4324]
#  [ 1.5676  2.8177]]
#
# T_duggal
#  [[ 2.671  -2.3346]
#  [ 1.6654  3.329 ]]
#
# |T|U [[ 2.671  -2.3346]
#  [ 1.6654  3.329 ]]
#
# T_hat(7)
#  [[ 2.9266 -2.3835]
#  [ 1.6165  3.0734]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 2.9266 -2.3835]
#  [ 1.6165  3.0734]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(7)
#  [[ 2.9266 -2.3835]
#  [ 1.6165  3.0734]]
#
# W
#  [[-0.8332  0.553 ]
#  [ 0.553   0.8332]]
#
# Sigma
#  [[3.996  0.    ]
#  [0.     3.2151]]
#
# V_h
#  [[-0.3865  0.9223]
#  [ 0.9223  0.3865]]
#
# W\Sigma V^*
#  [[ 2.9266 -2.3835]
#  [ 1.6165  3.0734]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.38654565  0.92227027]
#  [ 0.92227027  0.38654565]]
#
# Sigma_pinv
#  [[0.2503 0.    ]
#  [0.     0.311 ]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[ 3.3318 -0.2784]
#  [-0.2784  3.8793]]
#
# U|T|
#  [[ 2.9266 -2.3835]
#  [ 1.6165  3.0734]]
#
# T_duggal
#  [[ 2.6178 -2.0798]
#  [ 1.9202  3.3822]]
#
# |T|U [[ 2.6178 -2.0798]
#  [ 1.9202  3.3822]]
#
# T_hat(8)
#  [[ 2.7722 -2.2316]
#  [ 1.7684  3.2278]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 2.7722 -2.2316]
#  [ 1.7684  3.2278]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(8)
#  [[ 2.7722 -2.2316]
#  [ 1.7684  3.2278]]
#
# W
#  [[-0.6372  0.7707]
#  [ 0.7707  0.6372]]
#
# Sigma
#  [[3.9304 0.    ]
#  [0.     3.2807]]
#
# V_h
#  [[-0.1027  0.9947]
#  [ 0.9947  0.1027]]
#
# W\Sigma V^*
#  [[ 2.7722 -2.2316]
#  [ 1.7684  3.2278]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[-0.10270046  0.99471233]
#  [ 0.99471233  0.10270046]]
#
# Sigma_pinv
#  [[0.2544 0.    ]
#  [0.     0.3048]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[ 3.2875 -0.0664]
#  [-0.0664  3.9236]]
#
# U|T|
#  [[ 2.7722 -2.2316]
#  [ 1.7684  3.2278]]
#
# T_duggal
#  [[ 2.6986 -1.8788]
#  [ 2.1212  3.3014]]
#
# |T|U [[ 2.6986 -1.8788]
#  [ 2.1212  3.3014]]
#
# T_hat(9)
#  [[ 2.7354 -2.0552]
#  [ 1.9448  3.2646]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 2.7354 -2.0552]
#  [ 1.9448  3.2646]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# ===============<START>===============
#
# T_hat(9)
#  [[ 2.7354 -2.0552]
#  [ 1.9448  3.2646]]
#
# W
#  [[-0.3865  0.9223]
#  [ 0.9223  0.3865]]
#
# Sigma
#  [[3.8759 0.    ]
#  [0.     3.3352]]
#
# V_h
#  [[ 0.19    0.9818]
#  [ 0.9818 -0.19  ]]
#
# W\Sigma V^*
#  [[ 2.7354 -2.0552]
#  [ 1.9448  3.2646]]
#
# WV^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# V
#  [[ 0.18995808  0.9817922 ]
#  [ 0.9817922  -0.18995808]]
#
# Sigma_pinv
#  [[0.258  0.    ]
#  [0.     0.2998]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.8321 -0.5547]
#  [ 0.5547  0.8321]]
#
# |T|
#  [[3.3547 0.1008]
#  [0.1008 3.8564]]
#
# U|T|
#  [[ 2.7354 -2.0552]
#  [ 1.9448  3.2646]]
#
# T_duggal
#  [[ 2.8472 -1.777 ]
#  [ 2.223   3.1528]]
#
# |T|U [[ 2.8472 -1.777 ]
#  [ 2.223   3.1528]]
#
# T_hat(10)
#  [[ 2.7913 -1.9161]
#  [ 2.0839  3.2087]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 2.7913 -1.9161]
#  [ 2.0839  3.2087]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %%
print("Frobenius norm ")
count = 0
for i in Transformer.normal_info:
    print("F_",count,"=",i)
    count +=1
# Out:
# Frobenius norm
# F_ 0 = 16.0
# F_ 1 = 13.312804709405496
# F_ 2 = 11.076923076923078
# F_ 3 = 9.216557106511491
# F_ 4 = 7.668639053254435
# F_ 5 = 6.38069338143104
# F_ 6 = 5.309057806099227
# F_ 7 = 4.417403110221494
# F_ 8 = 3.6755015580687025
# F_ 9 = 3.0582021532302646
# F_ 10 = 2.544578001739864
# F_ 11 = 2.1172168753132534
# F_ 12 = 1.7616309242814434
# F_ 13 = 1.46576552906302
# F_ 14 = 1.2195906398871499
# F_ 15 = 1.0147607508897833
# F_ 16 = 0.8443319814603315
# F_ 17 = 0.7025266736929269
# F_ 18 = 0.5845375256263882
# F_ 19 = 0.4863646202489488
# F_ 20 = 0.4046798254336525
# F_ 21 = 0.3367139678646564
# F_ 22 = 0.2801629560694456
# F_ 23 = 0.2331096700601413
# F_ 24 = 0.19395896958653513
# F_ 25 = 0.16138361773394344
# F_ 26 = 0.13427928663683525
# F_ 27 = 0.11172711996965377
# F_ 28 = 0.0929625830562648
# F_ 29 = 0.07734954459437343
# F_ 30 = 0.06435871134664511
# F_ 31 = 0.053549684719175365
# F_ 32 = 0.044556030932286744
# F_ 33 = 0.037072858651735895
# F_ 34 = 0.030846482953126673
# F_ 35 = 0.0256658252204343
# F_ 36 = 0.021355257429089874
# F_ 37 = 0.01776864822953702
# F_ 38 = 0.014784408989366445
# F_ 39 = 0.012301371851211978
# F_ 40 = 0.01023536006956016
# F_ 41 = 0.008516334358533472
# F_ 42 = 0.007086018509694129
# F_ 43 = 0.00589592378667824
# F_ 44 = 0.00490570512210158
# F_ 45 = 0.004081793390773378
# F_ 46 = 0.0033962573922190656
# F_ 47 = 0.002825856962845778
# F_ 48 = 0.002351255117695971
# F_ 49 = 0.001956362512740449
# F_ 50 = 0.0016277920045589883

# %%
T=np.matrix([3/5,4/5,-4/5,3/5]).reshape(2,2)
Transformer=MeanTrans()
Transformer.transform(T,50)

Transformer.normal_calculator()
Transformer.normal_plot()
Transformer.process(1)

T_2 = Transformer[2]
print(np.linalg.eig(T)[0])
print(np.linalg.eig(T_2)[0])
abs(np.linalg.eig(T)[0][0])
# Out:
# ===============<START>===============
#
# T_hat(0)
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# W
#  [[-0.6  0.8]
#  [ 0.8  0.6]]
#
# Sigma
#  [[1. 0.]
#  [0. 1.]]
#
# V_h
#  [[-1. -0.]
#  [ 0.  1.]]
#
# W\Sigma V^*
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# WV^*
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# V
#  [[-1.  0.]
#  [-0.  1.]]
#
# Sigma_pinv
#  [[1. 0.]
#  [0. 1.]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# |T|
#  [[1. 0.]
#  [0. 1.]]
#
# U|T|
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# T_duggal
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# |T|U [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# T_hat(1)
#  [[ 0.6  0.8]
#  [-0.8  0.6]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 0.6  0.8]
#  [-0.8  0.6]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# [0.6+0.8j 0.6-0.8j]
# [0.6+0.8j 0.6-0.8j]
# 0.9999999999999999

# %%
T = np.matrix([1,2,-2/3,1/3]).reshape(2, 2)
Transformer = MeanTrans()
Transformer.transform(T, 50)

Transformer.normal_calculator()
Transformer.normal_plot()
Transformer.process(1)

T_2 = Transformer[2]
print(np.linalg.eig(T)[0])
print(np.linalg.eig(T_2)[0])
abs(np.linalg.eig(T)[0][0])
# Out:
# ===============<START>===============
#
# T_hat(0)
#  [[ 0.6667  0.6667]
#  [-0.6667  0.3333]]
#
# W
#  [[-0.8944  0.4472]
#  [ 0.4472  0.8944]]
#
# Sigma
#  [[1.     0.    ]
#  [0.     0.6667]]
#
# V_h
#  [[-0.8944 -0.4472]
#  [-0.4472  0.8944]]
#
# W\Sigma V^*
#  [[ 0.6667  0.6667]
#  [-0.6667  0.3333]]
#
# WV^*
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# V
#  [[-0.89442719 -0.4472136 ]
#  [-0.4472136   0.89442719]]
#
# Sigma_pinv
#  [[1.  0. ]
#  [0.  1.5]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.6  0.8]
#  [-0.8  0.6]]
#
# |T|
#  [[0.9333 0.1333]
#  [0.1333 0.7333]]
#
# U|T|
#  [[ 0.6667  0.6667]
#  [-0.6667  0.3333]]
#
# T_duggal
#  [[ 0.4533  0.8267]
#  [-0.5067  0.5467]]
#
# |T|U [[ 0.4533  0.8267]
#  [-0.5067  0.5467]]
#
# T_hat(1)
#  [[ 0.56    0.7467]
#  [-0.5867  0.44  ]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 0.56    0.7467]
#  [-0.5867  0.44  ]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr
# [0.5+0.64549722j 0.5-0.64549722j]
# [0.5+0.66396118j 0.5-0.66396118j]
# 0.8164965809277259

# %%
T=np.matrix([-10,-1,-3,100]).reshape(2,2)
# T = np.matrix([1,2,-2/3,1/3]).reshape(2, 2)
Transformer = MeanTrans()
Transformer.transform(T, 50)

Transformer.normal_calculator()
Transformer.normal_plot()

for i in range(50):
    A=Transformer[i]
    lam,mu=np.linalg.eig(A)[0]
    print(lam,mu,lam+mu,lam*mu)
    print(np.linalg.det(A))
    print()
# Out:
# -10.027265968790417 100.02726596879042 90.0 -1002.9999999999999
# -1003.0000000000003
#
# -10.036351623268047 100.0363516232681 90.00000000000006 -1003.9999999999999
# -1004.0000000000016
#
# -10.036351623268047 100.0363516232681 90.00000000000006 -1003.9999999999999
# -1004.0000000000016
#
# -10.036351623268075 100.03635162326813 90.00000000000006 -1004.0000000000031
# -1004.0000000000025
#
# -10.036351623268075 100.03635162326816 90.00000000000009 -1004.0000000000033
# -1004.0000000000033
#
# -10.036351623268061 100.03635162326819 90.00000000000013 -1004.0000000000022
# -1004.0000000000033
#
# -10.036351623268075 100.03635162326822 90.00000000000014 -1004.0000000000039
# -1004.0000000000033
#
# -10.036351623268075 100.03635162326825 90.00000000000017 -1004.0000000000042
# -1004.0000000000051
#
# -10.036351623268075 100.03635162326827 90.0000000000002 -1004.0000000000044
# -1004.0000000000051
#
# -10.036351623268075 100.0363516232683 90.00000000000023 -1004.0000000000048
# -1004.0000000000051
#
# -10.036351623268075 100.03635162326833 90.00000000000026 -1004.0000000000051
# -1004.0000000000069
#
# -10.03635162326809 100.03635162326836 90.00000000000027 -1004.0000000000068
# -1004.0000000000069
#
# -10.036351623268104 100.03635162326839 90.00000000000028 -1004.0000000000085
# -1004.0000000000069
#
# -10.036351623268104 100.03635162326842 90.00000000000031 -1004.0000000000088
# -1004.0000000000086
#
# -10.036351623268104 100.03635162326844 90.00000000000034 -1004.0000000000091
# -1004.0000000000086
#
# -10.036351623268104 100.03635162326847 90.00000000000037 -1004.0000000000093
# -1004.0000000000095
#
# -10.036351623268104 100.0363516232685 90.0000000000004 -1004.0000000000097
# -1004.0000000000105
#
# -10.036351623268104 100.03635162326853 90.00000000000043 -1004.0000000000099
# -1004.0000000000114
#
# -10.036351623268104 100.03635162326856 90.00000000000045 -1004.0000000000102
# -1004.0000000000114
#
# -10.036351623268132 100.03635162326859 90.00000000000045 -1004.0000000000133
# -1004.0000000000123
#
# -10.036351623268132 100.03635162326862 90.00000000000048 -1004.0000000000136
# -1004.0000000000132
#
# -10.036351623268132 100.03635162326864 90.00000000000051 -1004.0000000000139
# -1004.000000000014
#
# -10.036351623268132 100.03635162326867 90.00000000000054 -1004.0000000000142
# -1004.0000000000149
#
# -10.036351623268132 100.0363516232687 90.00000000000057 -1004.0000000000144
# -1004.0000000000149
#
# -10.036351623268132 100.03635162326873 90.0000000000006 -1004.0000000000148
# -1004.0000000000158
#
# -10.036351623268146 100.03635162326877 90.00000000000063 -1004.0000000000166
# -1004.0000000000167
#
# -10.036351623268146 100.0363516232688 90.00000000000065 -1004.0000000000168
# -1004.0000000000167
#
# -10.036351623268146 100.03635162326884 90.0000000000007 -1004.0000000000173
# -1004.0000000000176
#
# -10.036351623268146 100.03635162326887 90.00000000000072 -1004.0000000000176
# -1004.0000000000185
#
# -10.036351623268146 100.0363516232689 90.00000000000075 -1004.0000000000178
# -1004.0000000000194
#
# -10.03635162326816 100.03635162326893 90.00000000000077 -1004.0000000000196
# -1004.0000000000194
#
# -10.03635162326816 100.03635162326896 90.0000000000008 -1004.0000000000199
# -1004.0000000000202
#
# -10.03635162326816 100.03635162326898 90.00000000000082 -1004.0000000000201
# -1004.0000000000211
#
# -10.03635162326816 100.03635162326901 90.00000000000085 -1004.0000000000205
# -1004.0000000000211
#
# -10.03635162326816 100.03635162326904 90.00000000000088 -1004.0000000000207
# -1004.000000000023
#
# -10.036351623268189 100.03635162326907 90.00000000000088 -1004.0000000000239
# -1004.000000000023
#
# -10.036351623268189 100.0363516232691 90.00000000000091 -1004.0000000000241
# -1004.000000000023
#
# -10.036351623268189 100.03635162326913 90.00000000000094 -1004.0000000000244
# -1004.0000000000248
#
# -10.036351623268189 100.03635162326916 90.00000000000097 -1004.0000000000247
# -1004.0000000000248
#
# -10.036351623268189 100.03635162326921 90.00000000000102 -1004.0000000000252
# -1004.0000000000265
#
# -10.036351623268189 100.03635162326924 90.00000000000105 -1004.0000000000256
# -1004.0000000000265
#
# -10.036351623268203 100.03635162326927 90.00000000000107 -1004.0000000000273
# -1004.0000000000265
#
# -10.036351623268217 100.0363516232693 90.00000000000108 -1004.000000000029
# -1004.0000000000283
#
# -10.036351623268203 100.03635162326933 90.00000000000112 -1004.0000000000279
# -1004.0000000000283
#
# -10.036351623268217 100.03635162326938 90.00000000000117 -1004.0000000000298
# -1004.0000000000301
#
# -10.036351623268217 100.03635162326941 90.0000000000012 -1004.0000000000301
# -1004.0000000000301
#
# -10.036351623268217 100.03635162326944 90.00000000000122 -1004.0000000000304
# -1004.000000000031
#
# -10.036351623268217 100.03635162326947 90.00000000000125 -1004.0000000000307
# -1004.0000000000318
#
# -10.036351623268217 100.0363516232695 90.00000000000128 -1004.0000000000309
# -1004.0000000000327
#
# -10.036351623268246 100.03635162326952 90.00000000000128 -1004.0000000000341
# -1004.0000000000327

# %% [markdown]
# To satisfy the given conditions, we can let:
#
# $T=\begin{pmatrix} a & b \ -b & a \end{pmatrix}$
#
# where $a,b\in\mathbb{R}$ satisfy $b > 0$ and $\det(T) = ad - bc = a^2 + b^2 = 1$.
#
# Then, the characteristic equation of $T$ is:
#
# $\det(T - \lambda I) = \begin{vmatrix} a-\lambda & b \ -b & a-\lambda \end{vmatrix} = (a-\lambda)^2 + b^2 = (\lambda - u - iv)(\lambda - u + iv)$
#
# where $\lambda = u + iv$ and $\mu = u - iv$ are the eigenvalues of $T$.
#
# Expanding the determinant, we get:
#
# $(a-\lambda)^2 + b^2 = a^2 - 2a\lambda + \lambda^2 + b^2 = (\lambda - u)^2 + v^2 + b^2$
#
# Equating the real and imaginary parts of this expression, we get:
#
# $a^2 - 2au + u^2 + b^2 = (\lambda - u)^2 + b^2 = (\lambda - u)^2 + (\mu - u)^2$
#
# $-2av + 2v\mu = 2v^2$
#
# Simplifying, we get:
#
# $2u^2 + 2v^2 - 2au = 0$
#
# $v(\lambda - \mu) = 0$
#
# Since $v > 0$, we must have $\lambda = u + iv$ and $\mu = u - iv$ as the two roots of the characteristic equation.
#
# We can choose $a = \frac{1}{\sqrt{2}}$ and $b = \frac{1}{\sqrt{2}}$, then:
#
# $T=\begin{pmatrix} \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \ -\frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix}$
#
# and we have:
#
# $\lambda = u + iv = \frac{1}{\sqrt{2}} + i\frac{1}{\sqrt{2}}$
#
# $\mu = u - iv = \frac{1}{\sqrt{2}} - i\frac{1}{\sqrt{2}}$

# %%
a = np.sqrt(2)
T=np.matrix([1/a,a,0,complex(0,1/a)]).reshape(2,2)
# T = np.matrix([1,2,-2/3,1/3]).reshape(2, 2)
Transformer = MeanTrans()
Transformer.transform(T, 50)

Transformer.normal_calculator()
Transformer.normal_plot()


print(T@T.H-T.H@T)
print(sum(np.linalg.eig(T)[0]))

T_1=Transformer[1]
print(sum(np.linalg.eig(T_1)[0]))

print(np.linalg.eig(T)[0])
print(np.linalg.eig(T_1)[0])
# Out:
# [[ 2.+0.j -1.-1.j]
#  [-1.+1.j -2.+0.j]]
# (0.7071067811865475+0.7071067811865475j)
# (0.7071067811865479+0.7071067811865477j)
# [0.70710678+0.j         0.        +0.70710678j]
# [ 0.91257038-0.2054636j  -0.2054636 +0.91257038j]

# %%
T=np.matrix([complex(0,1),2,0,complex(0,-1)]).reshape(2,2)
# T = np.matrix([1,2,-2/3,1/3]).reshape(2, 2)
Transformer = MeanTrans()
Transformer.transform(T, 50)

Transformer.normal_calculator()
Transformer.normal_plot()


print(T@T.H-T.H@T)
print(sum(np.linalg.eig(T)[0]))

T_1=Transformer[1]
print(T_1)
print(sum(np.linalg.eig(T_1)[0]))

print(np.linalg.eig(T)[0])
print(np.linalg.eig(T_1)[0])

lam,mu=np.linalg.eig(T)[0]
print(lam+mu)
print(lam*mu)

lam,mu=np.linalg.eig(T_1)[0]
print(lam,mu)
print(lam+mu)
print(lam*mu)

Transformer.process(1)
# Out:
# [[ 4.+0.j  0.+4.j]
#  [ 0.-4.j -4.+0.j]]
# 0j
# [[ 0.+1.j  1.+0.j]
#  [-1.+0.j  0.-1.j]]
# (-1.3877787807814457e-17-4.440892098500626e-16j)
# [0.+1.j 0.-1.j]
# [ 0.00000000e+00+1.41421356j -1.38777878e-17-1.41421356j]
# 0j
# (1+0j)
# 1.4142135623730943j (-1.3877787807814457e-17-1.4142135623730947j)
# (-1.3877787807814457e-17-4.440892098500626e-16j)
# (1.9999999999999984-1.9626155733547177e-17j)
# ===============<START>===============
#
# T_hat(0)
#  [[0.+1.j 2.+0.j]
#  [0.+0.j 0.-1.j]]
#
# W
#  [[ 0.    -0.9239j  0.    -0.3827j]
#  [-0.3827+0.j      0.9239+0.j    ]]
#
# Sigma
#  [[2.4142 0.    ]
#  [0.     0.4142]]
#
# V_h
#  [[-0.3827+0.j      0.    +0.9239j]
#  [-0.9239+0.j      0.    -0.3827j]]
#
# W\Sigma V^*
#  [[0.+1.j 2.+0.j]
#  [0.+0.j 0.-1.j]]
#
# WV^*
#  [[ 0.    +0.7071j  0.7071+0.j    ]
#  [-0.7071+0.j      0.    -0.7071j]]
#
# V
#  [[-0.38268343-0.j         -0.92387953-0.j        ]
#  [ 0.        -0.92387953j  0.        +0.38268343j]]
#
# Sigma_pinv
#  [[0.4142 0.    ]
#  [0.     2.4142]]
#
# U=W\Sigma\Sigma_pinv V^*
#  [[ 0.    +0.7071j  0.7071+0.j    ]
#  [-0.7071+0.j      0.    -0.7071j]]
#
# |T|
#  [[0.7071+0.j     0.    -0.7071j]
#  [0.    +0.7071j 2.1213+0.j    ]]
#
# U|T|
#  [[ 0.+1.j  2.+0.j]
#  [-0.+0.j  0.-1.j]]
#
# T_duggal
#  [[ 0.+1.j  0.+0.j]
#  [-2.+0.j  0.-1.j]]
#
# |T|U [[ 0.+1.j  0.+0.j]
#  [-2.+0.j  0.-1.j]]
#
# T_hat(1)
#  [[ 0.+1.j  1.+0.j]
#  [-1.+0.j  0.-1.j]] ------->(a)
#
# ===============<END>===============
#
# result from our Method
#  [[ 0.+1.j  1.+0.j]
#  [-1.+0.j  0.-1.j]] ------->(b)
# If a!=b, Error.. ; If that happens, please email us
# e-mail : alsdn0110@snu.ac.kr

# %% [markdown]
# #### Last Update
#
# ---
#
#
# 2023/02/23 Min Woo Park (alsdn0110@snu.ac.kr)
